# %%
# %pip install -q langchain-ollama
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ollama list
# Out:
# ]11;?\NAME          ID              SIZE      MODIFIED
# gemma4:e4b    c6eb396dbd59    9.6 GB    25 minutes ago

# %%
from langchain_ollama import ChatOllama

chat = ChatOllama(model='gemma4:e4b')
chat.invoke("프랑스의 수도가 어디야?")
# Out:
# AIMessage(content='프랑스의 수도는 **파리**입니다.', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-06-17T08:53:42.691348Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6272813458, 'load_duration': 3355208250, 'prompt_eval_count': 24, 'prompt_eval_duration': 140311000, 'eval_count': 154, 'eval_duration': 2772941000, 'logprobs': None, 'model_name': 'gemma4:e4b'}, id='run--019ed4c9-3420-72b0-b5cb-8c795fb0d7ea-0', usage_metadata={'input_tokens': 24, 'output_tokens': 154, 'total_tokens': 178})

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate(
    template="What is the capital of {country}?",
    input_variables=["country"],
)

prompt = prompt_template.invoke({'country': 'Japan'})
print("created prompt:", prompt)
# Out:
# created prompt: text='What is the capital of Japan?'

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

message_list = [
    SystemMessage(content='you are a helpful assistant! 💪'),
    HumanMessage(content="What is the capital of South Korea?"),
    AIMessage(content="The capital of South Korea is Seoul. 😎"),
    HumanMessage(content="What is the capital of Germany?"),
]

chat.invoke(message_list)
# Out:
# AIMessage(content='The capital of Germany is **Berlin**. 🇩🇪', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-06-17T09:09:13.527501Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2293415625, 'load_duration': 227195709, 'prompt_eval_count': 57, 'prompt_eval_duration': 191100000, 'eval_count': 105, 'eval_duration': 1873674000, 'logprobs': None, 'model_name': 'gemma4:e4b'}, id='run--019ed4d7-77c0-7531-8bde-880cd9d3885d-0', usage_metadata={'input_tokens': 57, 'output_tokens': 105, 'total_tokens': 162})

# %%
chat.invoke(prompt)
# Out:
# AIMessage(content='The capital of Japan is **Tokyo**.', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-06-17T09:08:59.98441Z', 'done': True, 'done_reason': 'stop', 'total_duration': 532988917, 'load_duration': 231159750, 'prompt_eval_count': 23, 'prompt_eval_duration': 152904000, 'eval_count': 9, 'eval_duration': 146184000, 'logprobs': None, 'model_name': 'gemma4:e4b'}, id='run--019ed4d7-49ba-7ca2-b269-14df520ae718-0', usage_metadata={'input_tokens': 23, 'output_tokens': 9, 'total_tokens': 32})

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant!"),
    ("human", "What is the capital of {country}?"),
])

chat_prompt = chat_prompt_template.invoke({'country': 'America'})
print("created prompt:", chat_prompt)
print("==============")
print(chat.invoke(chat_prompt).content)
# Out:
# created prompt: messages=[SystemMessage(content='You are a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of America?', additional_kwargs={}, response_metadata={})]
# ==============
# The capital of the United States of America is **Washington, D.C.**
